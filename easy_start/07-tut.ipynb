# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
spark = SparkSession.builder.appName("MyApp").getOrCreate()

# %%
df = spark.read.csv("users.csv", header=True, inferSchema=True)

# %%
df.show()
# Out:
# +-------+-----+---+------+
# |user_id| name|age|  city|
# +-------+-----+---+------+
# |      1| Анна| 25|Москва|
# |      2| Иван| 30|   СПБ|
# |      3|Мария| 22|Москва|
# |      4| Петр| 35|Казань|
# |      5|Елена| 28|   СПБ|
# +-------+-----+---+------+

# %%
df2 = df.createOrReplaceTempView("users")

# %%
result = spark.sql("select * from users").show()
# Out:
# +-------+-----+---+------+
# |user_id| name|age|  city|
# +-------+-----+---+------+
# |      1| Анна| 25|Москва|
# |      2| Иван| 30|   СПБ|
# |      3|Мария| 22|Москва|
# |      4| Петр| 35|Казань|
# |      5|Елена| 28|   СПБ|
# +-------+-----+---+------+

# %%
result2 = spark.sql(
    """SELECT name, age
    FROM users
    WHERE name LIKE "А%" OR name LIKE "М%"
    AND age > 20"""
)

# %%
result2.show()
# Out:
# +-----+---+
# | name|age|
# +-----+---+
# | Анна| 25|
# |Мария| 22|
# +-----+---+
