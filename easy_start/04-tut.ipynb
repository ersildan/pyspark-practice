# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession
    .builder
    .appName("MyApplication")
    .getOrCreate()
)

# %%
df = spark.read.csv("users.csv", header=True)

# %%
df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- city: string (nullable = true)

# %%
df.show()
# Out:
# +-------+-----+---+------+
# |user_id| name|age|  city|
# +-------+-----+---+------+
# |      1| Анна| 25|Москва|
# |      2| Иван| 30|   СПБ|
# |      3|Мария| 22|Москва|
# |      4| Петр| 35|Казань|
# |      5|Елена| 28|   СПБ|
# +-------+-----+---+------+

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

# %%
schema = StructType([
    StructField(name="user_id", dataType=IntegerType(), nullable=True),
    StructField(name="name", dataType=StringType(), nullable=True),
    StructField(name="age", dataType=IntegerType(), nullable=True),
    StructField(name="city", dataType=StringType(), nullable=True)
])

# %%
df2 = spark.read.csv("users.csv", header=True, schema=schema)

# %%
df2.show()
# Out:
# +-------+-----+---+------+
# |user_id| name|age|  city|
# +-------+-----+---+------+
# |      1| Анна| 25|Москва|
# |      2| Иван| 30|   СПБ|
# |      3|Мария| 22|Москва|
# |      4| Петр| 35|Казань|
# |      5|Елена| 28|   СПБ|
# +-------+-----+---+------+

# %%
df2.describe()
# Out:
# DataFrame[summary: string, user_id: string, name: string, age: string, city: string]

# %%
df2.printSchema()
# Out:
# root
#  |-- user_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)

# %%
df3 = spark.read.csv("users.csv", header=True,  inferSchema=True)

# %%
df3.printSchema()
# Out:
# root
#  |-- user_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)

# %%
df.show()
# Out:
# +-------+-----+---+------+
# |user_id| name|age|  city|
# +-------+-----+---+------+
# |      1| Анна| 25|Москва|
# |      2| Иван| 30|   СПБ|
# |      3|Мария| 22|Москва|
# |      4| Петр| 35|Казань|
# |      5|Елена| 28|   СПБ|
# +-------+-----+---+------+

# %%
# %%bash
# head -10 users.csv
# Out:
# user_id,name,age,city
# 1,Анна,25,Москва
# 2,Иван,30,СПБ
# 3,Мария,22,Москва
# 4,Петр,35,Казань
# 5,Елена,28,СПБ

# %%
json_path = 'data/browser_events.jsonl'
df = spark.read.json(json_path, multiLine=False)

# %%
df.show()
# Out:
# +----------------+------------+--------------------+--------------------+--------------------+--------------------+----------+
# |browser_language|browser_name|  browser_user_agent|            click_id|            event_id|     event_timestamp|event_type|
# +----------------+------------+--------------------+--------------------+--------------------+--------------------+----------+
# |          sat_IN|      Chrome|Mozilla/5.0 (Linu...|811320f1-3bc2-42b...|8cca1c7d-b0cc-473...|2022-11-28 20:51:...|  pageview|
# |          tcy_IN|     Firefox|Mozilla/5.0 (Wind...|dd5a2b23-3357-4bb...|692733df-429d-420...|2022-11-28 20:51:...|  pageview|
------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- browser_language: string (nullable = true)
#  |-- browser_name: string (nullable = true)
#  |-- browser_user_agent: string (nullable = true)
#  |-- click_id: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- event_timestamp: string (nullable = true)
#  |-- event_type: string (nullable = true)

# %%
# %%bash
# head -20 'data/browser_events.jsonl'
# Out:
# {"event_id": "8cca1c7d-b0cc-4738-be92-c644101e3fff", "event_timestamp": "2022-11-28 20:51:05.627882", "event_type": "pageview", "click_id": "811320f1-3bc2-42b9-a841-5a1e5a812f2d", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit/531.2 (KHTML, like Gecko) Chrome/32.0.833.0 Safari/531.2", "browser_language": "sat_IN"}
# {"event_id": "692733df-429d-4208-a1d5-b1594895fa3c", "event_timestamp": "2022-11-28 20:51:10.914882", "event_type": "pageview", "click_id": "dd5a2b23-3357-4bba-857a-1afdb45f9144", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (Windows NT 5.0; iw-IL; rv:1.9.1.20) Gecko/2012-11-11 04:47:57 Firefox/3.6.11", "browser_language": "tcy_IN"}
# {"event_id": "1dc17a5c-3a3b-47fc-8b9f-9961d42cb56f", "event_timestamp": "2022-11-28 20:51:14.060882", "event_type": "pageview", "click_id": "811320f1-3bc2-42b9-a841-5a1e5a812f2d", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit/531.2 (KHTML, like Gecko) Chrome/32.0.833.0 Safari/531.2", "browser_language": "sat_IN"}
# {"event_id": "55318f64-86e5-4a20-a072-ea4dfcbf12d3", "event_timestamp": "2022-11-28 20:51:13.648882", "event_type": "pageview", "click_id": "7ab8087d-bfd4-4cb9-98bc-a4b05f4dee5a", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 7.1.2) AppleWebKit/533.2 (KHTML, like Gecko) Chrome/31.0.887.0 Safari/533.2", "browser_language": "mni_IN"}
# {"event_id": "90462d5d-26b7-486b-bfc7-c5ee1b7531d1", "event_timestamp": "2022-11-28 20:51:12.437882", "event_type": "pageview", "click_id": "58cdfc1e-85e0-4655-81dd-a5326244362e", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.2) AppleWebKit/533.0 (KHTML, like Gecko) Chrome/57.0.823.0 Safari/533.0", "browser_language": "ca_FR"}
# {"event_id": "f2b7dfb6-1276-4237-859e-cb10ead8c471", "event_timestamp": "2022-11-28 20:51:23.466882", "event_type": "pageview", "click_id": "58cdfc1e-85e0-4655-81dd-a5326244362e", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.2) AppleWebKit/533.0 (KHTML, like Gecko) Chrome/57.0.823.0 Safari/533.0", "browser_language": "ca_FR"}
# {"event_id": "324628ac-01fb-48a1-9001-f736d51a3e10", "event_timestamp": "2022-11-28 20:51:20.728882", "event_type": "pageview", "click_id": "9ffd819b-cce2-4882-8228-a7a96602e9ea", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gecko/2019-01-08 12:46:16 Firefox/3.6.6", "browser_language": "shs_CA"}
# {"event_id": "bfd43c21-b9a0-41a1-ba6c-0ee25fd9ccfa", "event_timestamp": "2022-11-28 20:51:22.984882", "event_type": "pageview", "click_id": "40463e2f-5d0f-4a37-ba66-de4f33241f0e", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (Android 7.1; Mobile; rv:62.0) Gecko/62.0 Firefox/62.0", "browser_language": "ps_AF"}
# {"event_id": "5a008922-71e5-4e4f-a91d-fcb3a30f7f20", "event_timestamp": "2022-11-28 20:51:32.362882", "event_type": "pageview", "click_id": "811320f1-3bc2-42b9-a841-5a1e5a812f2d", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit/531.2 (KHTML, like Gecko) Chrome/32.0.833.0 Safari/531.2", "browser_language": "sat_IN"}
# {"event_id": "cf6989cd-097f-49d9-ba45-592560f2ba72", "event_timestamp": "2022-11-28 20:51:30.552882", "event_type": "pageview", "click_id": "9ffd819b-cce2-4882-8228-a7a96602e9ea", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gecko/2019-01-08 12:46:16 Firefox/3.6.6", "browser_language": "shs_CA"}
# {"event_id": "c0adcd94-b21a-4f31-a4d9-96068fd5da37", "event_timestamp": "2022-11-28 20:51:29.830882", "event_type": "pageview", "click_id": "00c34225-4bc4-4bc5-972b-980d4578a9bb", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Macintosh; PPC Mac OS X 10_12_4) AppleWebKit/536.1 (KHTML, like Gecko) Chrome/13.0.808.0 Safari/536.1", "browser_language": "be_BY"}
# {"event_id": "26200c6d-22ab-443e-9870-872387f2929c", "event_timestamp": "2022-11-28 20:51:34.384882", "event_type": "pageview", "click_id": "c14483f2-235f-4cc8-8a6e-8af1459472d9", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (Windows NT 5.01; cv-RU; rv:1.9.2.20) Gecko/2012-06-10 05:47:40 Firefox/7.0", "browser_language": "el_CY"}
# {"event_id": "96d448a5-8f9c-4779-a1e6-bdcdb8f44b8d", "event_timestamp": "2022-11-28 20:51:41.731882", "event_type": "pageview", "click_id": "9ffd819b-cce2-4882-8228-a7a96602e9ea", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gecko/2019-01-08 12:46:16 Firefox/3.6.6", "browser_language": "shs_CA"}
# {"event_id": "824b15ef-eb10-4da7-883f-f77da89764b0", "event_timestamp": "2022-11-28 20:51:42.891882", "event_type": "pageview", "click_id": "8a211063-214e-4251-af70-b60a2ce40a04", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_4) AppleWebKit/534.1 (KHTML, like Gecko) Chrome/35.0.898.0 Safari/534.1", "browser_language": "zu_ZA"}
# {"event_id": "677337df-185c-4945-9913-386098d06239", "event_timestamp": "2022-11-28 20:51:39.331882", "event_type": "pageview", "click_id": "1cc4edcc-2277-4ed1-8b6b-964ccba05b56", "browser_name": "Firefox", "browser_user_agent": "Mozilla/5.0 (Windows NT 6.2; eu-FR; rv:1.9.1.20) Gecko/2016-05-20 17:29:14 Firefox/15.0", "browser_language": "sc_IT"}
# {"event_id": "68546203-eb01-4f31-87d1-27228cc9aef0", "event_timestamp": "2022-11-28 20:51:50.953882", "event_type": "pageview", "click_id": "615663e8-caea-4367-9cbc-dbbef09aad4a", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Windows NT 5.01) AppleWebKit/536.2 (KHTML, like Gecko) Chrome/57.0.867.0 Safari/536.2", "browser_language": "ca_ES"}
# {"event_id": "9b39d55f-f4c0-4fd5-9247-a64b780f8885", "event_timestamp": "2022-11-28 20:51:54.196882", "event_type": "pageview", "click_id": "58cdfc1e-85e0-4655-81dd-a5326244362e", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.2) AppleWebKit/533.0 (KHTML, like Gecko) Chrome/57.0.823.0 Safari/533.0", "browser_language": "ca_FR"}
# {"event_id": "d41e2d61-5e74-48a7-a08e-d3cc51498e70", "event_timestamp": "2022-11-28 20:52:06.576882", "event_type": "pageview", "click_id": "615663e8-caea-4367-9cbc-dbbef09aad4a", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Windows NT 5.01) AppleWebKit/536.2 (KHTML, like Gecko) Chrome/57.0.867.0 Safari/536.2", "browser_language": "ca_ES"}
# {"event_id": "997b2317-c17c-4cb1-89b7-bcf744f1aedb", "event_timestamp": "2022-11-28 20:52:06.727882", "event_type": "pageview", "click_id": "58cdfc1e-85e0-4655-81dd-a5326244362e", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Linux; Android 2.3.2) AppleWebKit/533.0 (KHTML, like Gecko) Chrome/57.0.823.0 Safari/533.0", "browser_language": "ca_FR"}
# {"event_id": "7cf47eec-0d68-4fed-abb7-de741f989e73", "event_timestamp": "2022-11-28 20:52:04.501882", "event_type": "pageview", "click_id": "ddfe3e04-333a-4544-b26e-2b1e45f2ed84", "browser_name": "Chrome", "browser_user_agent": "Mozilla/5.0 (Windows 98; Win 9x 4.90) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/33.0.886.0 Safari/532.0", "browser_language": "ur_PK"}
